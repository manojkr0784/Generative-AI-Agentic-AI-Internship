# %%
#pip install -U langchain-google-genai

# %%
pip install -U langchain-google-genai

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = "AQ.A*****************************-Yobgprw"

# %%
model=init_chat_model("google_genai:gemini-2.5-flash")

# %%
response=model.invoke("What is the capital of France?")
print(response.text)
# Out:
# The capital of France is Paris.

# %%
response
# Out:
# AIMessage(content='The capital of France is **Paris**.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e9c6c-ff75-7d22-87d6-4b5ae4c06dbd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 38, 'total_tokens': 46, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 30}})

# %%
response=model.invoke("Tabular data for Generative Ai vs Agentic AI vs model context protocol")
print(response.text)
# Out:
# Let's break down Generative AI, Agentic AI, and Model Context Protocol into a tabular comparison. While Generative AI and Agentic AI are types of AI systems, the Model Context Protocol is a technique or set of strategies used *within* or *with* these AI systems, particularly those based on large language models (LLMs).
#
# ---
#
# ## Generative AI vs. Agentic AI vs. Model Context Protocol
#
# | Feature             | Generative AI                                 | Agentic AI                                      | Model Context Protocol                              |
# | :------------------ | :-------------------------------------------- | :---------------------------------------------- | :-------------------------------------------------- |
# ...

# %% [markdown]
# # Language Translation

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages=[
    SystemMessage("Translate the following from English to hindi language."),
    HumanMessage("How are you team working on langchain with google gemini model?")
]
model.invoke(messages)
# Out:
# AIMessage(content='आपकी टीम लैंगचेन पर गूगल जेमिनी मॉडल के साथ कैसे काम कर रही है?\n\nया\n\nलैंगचेन पर गूगल जेमिनी मॉडल के साथ आपकी टीम का काम कैसा चल रहा है?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e9cad-1b9a-7942-851b-b0dce8b8f3da-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 23, 'output_tokens': 988, 'total_tokens': 1011, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 946}})

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages=[
    SystemMessage("Translate the following from hindi to  English language."),
    HumanMessage("लैंगचेन पर गूगल जेमिनी मॉडल के साथ आपकी टीम का काम कैसा चल रहा है?")
]
model.invoke(messages)
# Out:
# AIMessage(content="How is your team's work going with the Google Gemini model on LangChain?", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e9caf-0e09-7b03-9552-91cf5c6ae910-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 31, 'output_tokens': 673, 'total_tokens': 704, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 656}})

# %%
messages=[
    SystemMessage("Translate the following from hindi to  English language."),
    HumanMessage("बहुत अच्छा काम कर रहे हो आप लोग")
]
model.invoke(messages)
# Out:
# AIMessage(content='Here are a few ways to translate "बहुत अच्छा काम कर रहे हो आप लोग" into English, depending on the nuance you want to convey:\n\n1.  **You are doing very good work.** (Direct and formal)\n2.  **You are doing great work.** (A bit more enthusiastic)\n3.  **You\'re doing a great job.** (Very common and natural way to express this)\n4.  **You\'re doing excellent work.** (Strong and appreciative)\n5.  **You all are doing a fantastic job.** (Emphasizes "आप लोग" and adds strong enthusiasm)\n\nThe most common and natural translation in everyday conversation would likely be: **"You\'re doing a great job!"** or **"You are doing great work!"**', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e9cb4-c7ec-72d1-b1ea-6ddf5ff51361-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 786, 'total_tokens': 805, 'input_tok
# ...

# %%
response2=model.invoke(messages)
print(response2.text)
# Out:
# Here are a few ways to translate "बहुत अच्छा काम कर रहे हो आप लोग" into English, ranging from more literal to more natural:
#
# 1.  **You all are doing very good work.** (More literal)
# 2.  **You're all doing great work.** (More natural)
# 3.  **You're doing an excellent job.** (Very common and natural)
# 4.  **You guys are doing a fantastic job.** (Informal)
# 5.  **You people are doing very good work.** (Less common, and "you people" can sometimes sound a bit detached, though grammatically correct.)
#
# The most common and natural translations would be **"You're all doing great work!"** or **"You're doing an excellent job!"**
